# %% [markdown]
# # Projeto DCGAN Avançado: Geração de Rostos de Anime
#
# ## Premissa Fundamental (Objetivo Central)
# O objetivo principal deste projeto é **construir um modelo generativo profundo (DCGAN) estável, puramente convolucional e de alta fidelidade para criar rostos realistas de anime**. A arquitetura foi recalibrada para superar as falhas clássicas de borrões estruturais e colapso de modo (*Mode Collapse*) através de um equilíbrio matemático rigoroso e assimétrico entre o Gerador e o Discriminador.
#
# ---
#
# ### Pilares Estruturais do Projeto
#
# Para sustentar essa premissa, o código foi projetado sob três pilares práticos de engenharia de machine learning:
#
# 1. **Otimização de Infraestrutura e I/O**: Extração direta do dataset no armazenamento local da máquina virtual (`/content/`) para eliminar o gargalo de leitura de dados e acelerar o treinamento na GPU T4.
# 2. **Alta Capacidade Geométrica (`ch_base = 128`)**: Alargamento dos canais convolucionais internos e remoção completa de camadas lineares (`nn.Linear`) iniciais. Isso dá capacidade matemática à rede para desenhar traços complexos (como olhos, cabelos e expressões detalhadas) sem gerar borrões.
# 3. **Estabilidade Adversarial Ativa (`AdamW` + Taxas Assimétricas)**: Implementação de otimizadores com decaimento de peso para evitar artefatos visuais e calibração das taxas de aprendizado (mantendo o Discriminador 4 vezes mais lento que o Gerador) para garantir que o duelo entre as redes permaneça equilibrado ao longo de todas as épocas.

# %% [markdown]
# # Importação de Bibliotecas e Dependências
#
# Este bloco inicial carrega todas as ferramentas essenciais para a construção, treinamento e avaliação da nossa **DCGAN** (Deep Convolutional Generative Adversarial Network). A organização dos imports divide-se em três pilares principais:
#
# ### 1. O Coração do Framework (PyTorch)
# *   `torch` e `torch.nn`: Fornecem as estruturas matemáticas fundamentais e as camadas de redes neurais (como convoluções, normalizações e funções de ativação).
# *   `torch.optim`: Contém os algoritmos de otimização de gradiente. Usaremos variantes avançadas para ajustar os pesos dos nossos modelos.
#
# ### 2. Visão Computacional e Manipulação de Imagens (`torchvision`)
# *   `torchvision.transforms`: Define o pipeline de processamento que ajustará as dimensões, transformará as imagens reais em tensores matemáticos e normalizará os valores dos pixels.
# *   `DataLoader`: Gerencia o carregamento eficiente dos dados em lotes (*batches*), dividindo as tarefas utilizando os múltiplos núcleos do processador da máquina virtual.
# *   `save_image`: Função utilitária para exportar as grades de imagens sintéticas criadas pelo gerador diretamente para o disco do Colab.
#
# ### 3. Integração com o Ambiente Colab e Diagnósticos Visuais
# *   `google.colab.drive` e `zipfile`: Permitem montar o seu Google Drive de forma segura e extrair os arquivos compactados em altíssima velocidade para o armazenamento local.
# *   `numpy` e `matplotlib.pyplot`: Ferramentas matemáticas e gráficas indispensáveis para processar matrizes multidimensionais e renderizar na tela os rostos gerados, os comparativos de evolução e os testes de caminhada espacial no espaço latente.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.utils import save_image
from google.colab import drive
import zipfile
import os

# Adicione estes dois imports para suportar os blocos visuais e a interpolação:
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# # Integração com o Google Drive e Extração do Dataset
#
# Este bloco é responsável por gerenciar a infraestrutura de armazenamento e resolver o principal gargalo no treinamento de modelos de deep learning no Colab: a velocidade de leitura e escrita de dados (*I/O throughput*).
#
# ### Como funciona o processo:
# 1. **`drive.mount('/content/drive')`**: Realiza uma conexão segura entre a máquina virtual temporária que o Google te emprestou e o seu armazenamento pessoal do Google Drive.
# 2. **Estratégia de Extração Local**: Em vez de fazer o PyTorch ler milhares de arquivos pequenos de imagem diretamente do seu Drive (o que tornaria o treinamento extremamente lento devido ao limite de banda da conexão), o script localiza o arquivo compactado em `.zip`.
# 3. **`zipfile.ZipFile`**: Descompacta todo o volume de dados direto na pasta `/content/anime_data`, localizada no disco rígido virtual local (*SSD NVMe* da máquina virtual). Isso garante que o pipeline de dados carregue as imagens para a memória RAM e para a GPU de forma instantânea durante o treino.

# %%
# 1. Monta o Google Drive no ambiente do Colab
drive.mount('/content/drive')

# 2. Caminho do arquivo ZIP no seu Drive (ajuste o nome se for diferente)
zip_path = '/content/drive/MyDrive/archive (1).zip'
# Local rápido de extração na máquina virtual do Colab
extract_path = '/content/anime_data'

# 3. Descompacta o arquivo silenciosamente e com alta velocidade de I/O
if os.path.exists(zip_path):
    print("Descompactando o dataset no ambiente local do Colab...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print("Pronto! Dataset extraído em:", extract_path)
else:
    print(f"ERRO: O arquivo '{zip_path}' não foi encontrado no seu Google Drive.")
    print("Verifique se o nome do arquivo .zip está correto e se ele está na raiz do seu Drive.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Descompactando o dataset no ambiente local do Colab...
# Pronto! Dataset extraído em: /content/anime_data

# %% [markdown]
# # Hiperparâmetros, Alocação de Hardware e Pipeline de Dados
#
# Este bloco configura as variáveis estruturais da nossa inteligência artificial, detecta os recursos físicos de aceleração por hardware e monta o pipeline de processamento que alimentará as redes neurais.
#
# ### 1. Hiperparâmetros da DCGAN Avançada
# *   **`latent_dim = 100`**: Define o tamanho do nosso "vetor de ruído". São 100 variáveis numéricas geradas aleatoriamente que servem como sementes de criação. Cada combinação mapeia uma característica diferente (como cor de cabelo, expressão ou acessórios do personagem).
# *   **`img_shape = (3, 64, 64)`**: Define que trabalharemos com 3 canais de cores (RGB) em uma resolução quadrada estável de 64x64 pixels.
# *   **`ch_base = 128`**: É a engrenagem de alta fidelidade do modelo. Dobrar esse valor inicial para 128 permite que os mapas convolucionais internos fiquem muito mais largos, dando capacidade matemática à rede para renderizar pequenos detalhes sem gerar borrões.
#
# ### 2. Detecção Automática de Hardware (GPU)
# O comando `torch.device("cuda" ...)` verifica se você ativou a aceleração gráfica por hardware nas configurações do Colab. Caso o ambiente encontre a GPU (como a T4), os cálculos de retropropagação do gradiente passam a rodar em paralelo nas milhares de pequenas unidades de processamento da placa de vídeo, reduzindo drasticamente o tempo de cada época.
#
# ### 3. Pipeline de Transformação e Carga Segura
# *   **`transforms.Resize` & `ToTensor`**: Garante que qualquer variação de tamanho no dataset original seja contida em 64x64 e converte a matriz de pixels para tensores do PyTorch (escalonados entre `0.0` e `1.0`).
# *   **`transforms.Normalize`**: Modifica os valores de pixel para que variem na escala de `[-1.0, 1.0]`. Esse ajuste é crucial porque a função de ativação de saída do nosso Gerador é uma **Tanh** (Tangente Hiperbólica), que opera exatamente nessa mesma amplitude numérica.
# *   **`ImageFolder` & `DataLoader`**: Faz uma varredura nas pastas locais, mapeia as imagens e configura o carregamento em lotes (*batch_size = 64*) usando múltiplos núcleos de processamento da CPU (`num_workers=2`) para evitar gargalos na entrega de dados para a GPU.

# %%
latent_dim = 100
img_shape = (3, 64, 64) # Imagens RGB 64x64
batch_size = 64
epochs = 50
learning_rate = 0.0002
ch_base = 128  # ADICIONADO: Dobra os filtros base para maior riqueza de detalhes visuais
DATASET_PATH = "/content/anime_data" # Aponta para o disco local do Colab

# Configuração automática de hardware (Aproveitando a GPU T4 do Colab se ativa)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Rodando no dispositivo: {device}")
if device.type == 'cuda':
    print("GPU Detectada:", torch.cuda.get_device_name(0))

# Pipeline de transformação para 3 canais (RGB)
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    # Normaliza os 3 canais para o intervalo [-1.0, 1.0] exigido pela Tanh
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
])

# Carregamento seguro dos dados no Colab
if os.path.exists(DATASET_PATH):
    dataset = torchvision.datasets.ImageFolder(root=DATASET_PATH, transform=transform)
    # num_workers=2 otimiza o carregamento usando múltiplos núcleos da CPU do Colab
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=2)
    print(f"Dataset carregado com sucesso! Total de imagens: {len(dataset)}")
else:
    raise FileNotFoundError(f"A pasta '{DATASET_PATH}' não existe. Rode a Célula de automação primeiro.")
# Out:
# Rodando no dispositivo: cuda
# GPU Detectada: Tesla T4
# Dataset carregado com sucesso! Total de imagens: 43102

# %% [markdown]
# # Inicialização Estatística e Arquitetura do Gerador Profissional
#
# Este bloco define o mecanismo de calibração inicial da rede e constrói o **Gerador**, cuja única função é transformar um vetor abstrato de ruído aleatório em uma imagem estruturada e coerente de um rosto de anime.
#
# ### 1. Inicialização de Pesos (`weights_init`)
# Em redes neurais profundas, a forma como os pesos começam faz toda a diferença entre o modelo convergir ou falhar por completo. Esta função implementa a regra rigorosa proposta no paper oficial da **DCGAN**:
# *   **Camadas Convolucionais**: Os pesos são inicializados a partir de uma distribuição normal (Gaussiana) com média 0 e desvio padrão 0.02. Isso impede que os filtros comecem com valores extremos.
# *   **Camadas de BatchNorm**: Recebem média 1.0 para manter a variância dos dados estável no início e os vieses (*bias*) são zerados.
#
# ### 2. Arquitetura do Gerador (Mapeamento Progressivo)
# Esta rede opera de forma puramente convolucional. Foi removida qualquer camada linear (`nn.Linear`) inicial. O ruído quadridimensional $z$ com formato `(batch, 100, 1, 1)` entra direto na rede e passa por um processo de expansão espacial por meio de Convoluções Transpostas (`nn.ConvTranspose2d`):
#
# 1.  **Primeira Camada**: Recebe os 100 canais de ruído e projeta um mapa de características denso de dimensão **$4 \times 4$** com $1024$ canais (`ch_base * 8`).
# 2.  **Segunda Camada**: Expande a resolução para **$8 \times 8$** pixels e reduz os canais internos para 512.
# 3.  **Terceira Camada**: Dobra o tamanho espacial para **$16 \times 16$** pixels e reduz os canais para 256.
# 4.  **Quarta Camada**: Amplia para **$32 \times 32$** pixels com 128 canais.
# 5.  **Camada de Saída**: Conclui a expansão na resolução final de **$64 \times 64$** pixels, projetando os 3 canais de cor (RGB).
#
# ### 3. Funções de Ativação e Regularização
# *   **`nn.BatchNorm2d`**: Normaliza as saídas de cada camada convolucional antes de passarem para a próxima. Isso estabiliza o fluxo de gradientes, reduzindo a chance de o gerador sofrer colapso de modo (*Mode Collapse*).
# *   **`nn.ReLU(True)`**: Introduz a não-linearidade necessária para que a rede aprenda formas e curvas complexas de traços faciais.
# *   **`nn.Tanh()`**: Garante que os valores de saída de cada pixel fiquem estritamente confinados no intervalo de $[-1.0, 1.0]$, correspondendo à escala em que o nosso dataset real foi normalizado.

# %%
# Função essencial para inicializar os pesos conforme o paper original da DCGAN
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# ==========================================
# GERADOR DCGAN PROFISSIONAL (Alta Capacidade Estestrutural)
# ==========================================
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        # O modelo agora recebe diretamente o tensor z estruturado em (batch, 100, 1, 1)
        self.model = nn.Sequential(
            # Estado inicial: (100, 1, 1) -> Saída: (1024, 4, 4) se ch_base=128
            nn.ConvTranspose2d(latent_dim, ch_base * 8, kernel_size=4, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(ch_base * 8),
            nn.ReLU(True),

            # Estado: (1024, 4, 4) -> Saída: (512, 8, 8)
            nn.ConvTranspose2d(ch_base * 8, ch_base * 4, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(ch_base * 4),
            nn.ReLU(True),

            # Estado: (512, 8, 8) -> Saída: (256, 16, 16)
            nn.ConvTranspose2d(ch_base * 4, ch_base * 2, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(ch_base * 2),
            nn.ReLU(True),

            # Estado: (256, 16, 16) -> Saída: (128, 32, 32)
            nn.ConvTranspose2d(ch_base * 2, ch_base, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(ch_base),
            nn.ReLU(True),

            # Estado: (128, 32, 32) -> Saída: (3, 64, 64) [Canais RGB]
            nn.ConvTranspose2d(ch_base, 3, kernel_size=4, stride=2, padding=1, bias=False),
            nn.Tanh()
        )

    def forward(self, z):
        return self.model(z)

# %% [markdown]
# # Estrutura do Discriminador, Instanciação e Otimizadores Avançados
#
# Este bloco constrói o **Discriminador**, que atua como um classificador binário (um crítico de arte), instancia ambas as redes no hardware correto e configura os algoritmos de otimização matemática com técnicas de regularização.
#
# ### 1. Arquitetura do Discriminador (Extração Reversa)
# O Discriminador faz o processo geométrico inverso do Gerador. Ele recebe uma imagem colorida de dimensão $64 \times 64$ pixels e aplica convoluções com saltos (*strided convolutions*, `stride=2`) para compactar o tamanho espacial e extrair características profundas:
# *   **Camada Inicial**: Recebe os 3 canais RGB e reduz o espaço para **$32 \times 32$** com 128 canais (`ch_base`).
# *   **Camadas Intermediárias**: Compactam progressivamente a imagem passando pelas resoluções **$16 \times 16$** (256 canais), **$8 \times 8$** (512 canais) até atingir **$4 \times 4$** pixels com 1024 canais (`ch_base * 8`).
# *   **Classificação Pura Convolucional**: Uma última convolução sem margens (`padding=0`) reduz a estrutura restante para uma única matriz linear. A função **Sigmoid** mapeia esse valor para uma única probabilidade escalar contida entre `0.0` (imagem com certeza falsa) e `1.0` (imagem com certeza real).
#
# ### 2. Funções de Ativação Específicas
# *   **`nn.LeakyReLU(0.2)`**: Diferente da ReLU comum usada no Gerador, a LeakyReLU permite a passagem de uma pequena fração de gradiente negativo (multiplicado por 0.2) caso os neurônios fiquem inativos. Isso impede que o fluxo de gradientes morra completamente (*dying ReLU*), mantendo o aprendizado do Discriminador ativo.
#
# ### 3. Técnicas Avançadas de Otimização e Regularização
# *   **`optim.AdamW`**: Substituímos o Adam tradicional pelo AdamW. Ele separa matematicamente o decaimento de peso (*weight decay*) das estimativas de momentos do gradiente. O parâmetro `weight_decay=1e-5` restringe o crescimento desordenado dos pesos convolucionais, suavizando a geração e eliminando padrões serrilhados nas imagens de anime.
# *   **Assimetria das Taxas de Aprendizado**: Enquanto o Gerador utiliza `lr = 0.0002`, o Discriminador foi configurado com uma taxa desacelerada de **`0.00005`** (quatro vezes menor). Esse freio é vital para conter a velocidade do Discriminador, permitindo que as duas redes entrem em um equilíbrio saudável em vez de o classificador vencer o jogo de forma precoce.

# %%
# ==========================================
# DISCRIMINADOR DCGAN PROFISSIONAL (Alta Capacidade)
# ==========================================
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            # Entrada: (3, 64, 64) -> Saída: (128, 32, 32) se ch_base=128
            nn.Conv2d(3, ch_base, kernel_size=4, stride=2, padding=1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),

            # Estado: (128, 32, 32) -> Saída: (256, 16, 16)
            nn.Conv2d(ch_base, ch_base * 2, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(ch_base * 2),
            nn.LeakyReLU(0.2, inplace=True),

            # Estado: (256, 16, 16) -> Saída: (512, 8, 8)
            nn.Conv2d(ch_base * 2, ch_base * 2 * 2, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(ch_base * 4),
            nn.LeakyReLU(0.2, inplace=True),

            # Estado: (512, 8, 8) -> Saída: (1024, 4, 4)
            nn.Conv2d(ch_base * 4, ch_base * 4 * 2, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(ch_base * 8),
            nn.LeakyReLU(0.2, inplace=True),

            # Estado: (1024, 4, 4) -> Saída: (1, 1, 1) Classificação Pura Convolucional
            nn.Conv2d(ch_base * 8, 1, kernel_size=4, stride=1, padding=0, bias=False),
            nn.Flatten(),
            nn.Sigmoid()
        )

    def forward(self, img):
        return self.model(img)

# Instanciar redes de alta capacidade geométrica
generator = Generator().to(device)
discriminator = Discriminator().to(device)

# Aplica a inicialização de pesos Gaussiana do paper DCGAN
generator.apply(weights_init)
discriminator.apply(weights_init)

# Critério de perda padrão
criterion = nn.BCELoss().to(device)

# Otimizadores avançados (AdamW + Weight Decay) para contornos limpos e nítidos
optimizer_G = optim.AdamW(generator.parameters(), lr=learning_rate, betas=(0.5, 0.999), weight_decay=1e-5)
optimizer_D = optim.AdamW(discriminator.parameters(), lr=0.00005, betas=(0.5, 0.999), weight_decay=1e-5)

# Diretórios para salvar os resultados no Colab
OUTPUT_DIR = "/content/images_dgan"
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# %% [markdown]
# # O Loop de Treinamento Adversarial (Jogo Minimax)
#
# Este bloco executa o coração matemático do aprendizado por reforço adversarial. Trata-se de um jogo de soma zero onde duas redes neurais competem e evoluem de forma simultânea a cada iteração de dados.
#
# ### 1. Preparação Dinâmica dos Lotes (*Batches*)
# *   **`batch_curr_size`**: Captura o tamanho exato do lote atual. Isso é fundamental porque o último lote do conjunto de dados pode conter menos de 64 imagens residuais, evitando erros de incompatibilidade de dimensões nas funções de perda.
# *   **`real_labels` (com *Label Smoothing*)**: Em vez de definir alvos rígidos como `1.0` para imagens reais, multiplicamos o vetor por `0.9`. Essa suavização acalma a confiança cega do Discriminador, impedindo que ele zere suas perdas rápido demais e deixe de enviar gradientes úteis para o Gerador.
# *   **`fake_labels`**: Definido como `0.0`, representando o alvo absoluto para dados artificiais.
#
# ### 2. O Passo do Discriminador (Minimizar Erros de Classificação)
# O objetivo do Discriminador é aprender a separar as amostras reais das artificiais. O processo executa duas avaliações:
# 1.  **Etapa Real**: Processa os rostos de anime reais e calcula a perda (`real_loss`) comparando a previsão com as metas suavizadas de `0.9`.
# 2.  **Etapa Falsa**: O Gerador recebe um ruído quadridimensional aleatório `z` no formato correto de mapa de características `(batch_curr_size, latent_dim, 1, 1)` e produz um lote de imagens artificiais (`fake_imgs`). O Discriminador avalia essas imagens e calcula a perda (`fake_loss`) comparando as previsões com a meta `0.0`.
#     *   **`.detach()`**: Esta função é crítica. Ela congela o fluxo de cálculo do Gerador enquanto treinamos o Discriminador. Isso garante que os pesos do Gerador não sejam modificados por engano nesta etapa.
# 3.  As duas perdas são somadas em `d_loss`, os gradientes são propagados com `.backward()` e o otimizador atualiza apenas os pesos do Discriminador.
#
# ### 3. O Passo do Gerador (Maximizar a Ilusão Visual)
# Logo em seguida, é a vez de o Gerador ajustar os seus filtros para tentar enganar o seu rival:
# 1.  O Gerador passa o mesmo lote de imagens falsas criadas há pouco para o Discriminador ser reavaliado (desta vez sem usar o `.detach()`).
# 2.  A perda `g_loss` é calculada comparando a resposta do Discriminador com o vetor de alvos `real_labels` (`0.9`). **Aqui está o truque**: o Gerador quer que as imagens falsas dele recebam notas de imagens reais.
# 3.  O gradiente flui de volta por toda a estrutura do Discriminador (sem alterá-lo) e atinge os filtros convolucionais do Gerador, refinando as pinceladas que desenham os olhos, cabelos e traços dos rostos artificiais.
#
# ### 4. Exportação e Logs de Progresso
# A cada 100 lotes, o script exibe o balanço das perdas para acompanharmos a saúde do equilíbrio dinâmico. No término de cada época, as primeiras 25 imagens artificiais geradas pela rede são salvas em formato de grade ($5 \times 5$) no diretório `/content/images_dgan/`, permitindo o acompanhamento da evolução da IA ao longo do tempo.

# %%
# ==========================================
# FUNÇÃO DE TREINAMENTO (ADVERSARIAL LEARNING)
# ==========================================
def train_dcgan(generator, discriminator, dataloader, criterion, optimizer_G, optimizer_D, epochs):
    print("Iniciando o loop de treinamento...")
    for epoch in range(epochs):
        for i, (imgs, _) in enumerate(dataloader):
            batch_curr_size = imgs.size(0)

            # Definição dinâmica de alvos reais (com Label Smoothing 0.9) e falsos
            real_labels = (torch.ones(batch_curr_size, 1) * 0.9).to(device)
            fake_labels = torch.zeros(batch_curr_size, 1).to(device)

            # ----------------------------------
            # 1. PASSO DO DISCRIMINADOR
            # ----------------------------------
            optimizer_D.zero_grad()

            # Perda com imagens reais do dataset de anime
            real_imgs = imgs.to(device)
            real_loss = criterion(discriminator(real_imgs), real_labels)

            # AJUSTE: Amostragem do ruído z diretamente no formato 4D exigido pelo novo Gerador
            z = torch.randn(batch_curr_size, latent_dim, 1, 1).to(device)
            fake_imgs = generator(z)
            fake_loss = criterion(discriminator(fake_imgs.detach()), fake_labels)

            d_loss = real_loss + fake_loss
            d_loss.backward()
            optimizer_D.step()

            # ----------------------------------
            # 2. PASSO DO GERADOR
            # ----------------------------------
            optimizer_G.zero_grad()

            # O gerador quer que o discriminador ache que as imagens falsas são REAIS
            g_loss = criterion(discriminator(fake_imgs), real_labels)
            g_loss.backward()
            optimizer_G.step()

            # Exibe logs a cada 100 iterações para monitoramento do equilíbrio dinâmico
            if i % 100 == 0:
                print(f"Época [{epoch}/{epochs}] Batch {i}/{len(dataloader)} | Loss D: {d_loss.item():.4f} | Loss G: {g_loss.item():.4f}")

        # Salva uma grade contendo as primeiras 25 imagens artificiais geradas nesta época
        save_image(fake_imgs[:25], f"{OUTPUT_DIR}/anime_epoch_{epoch}.png", nrow=5, normalize=True)
        print(f"--> [FIM DA ÉPOCA {epoch}] Amostra visual salva em: {OUTPUT_DIR}/anime_epoch_{epoch}.png\n")

# Executar o loop de treinamento com a nova matemática
train_dcgan(generator, discriminator, dataloader, criterion, optimizer_G, optimizer_D, epochs)
# Out:
# Iniciando o loop de treinamento...
# Época [0/50] Batch 0/674 | Loss D: 2.3338 | Loss G: 2.4958
# Época [0/50] Batch 100/674 | Loss D: 2.2836 | Loss G: 7.2803
# Época [0/50] Batch 200/674 | Loss D: 2.2342 | Loss G: 3.0114
# Época [0/50] Batch 300/674 | Loss D: 2.0503 | Loss G: 1.3883
# Época [0/50] Batch 400/674 | Loss D: 1.8869 | Loss G: 2.0591
# Época [0/50] Batch 500/674 | Loss D: 1.8610 | Loss G: 1.3965
# Época [0/50] Batch 600/674 | Loss D: 1.6851 | Loss G: 1.0199
# --> [FIM DA ÉPOCA 0] Amostra visual salva em: /content/images_dgan/anime_epoch_0.png
#
# Época [1/50] Batch 0/674 | Loss D: 1.7553 | Loss G: 0.9593
# Época [1/50] Batch 100/674 | Loss D: 1.3869 | Loss G: 1.4383
# Época [1/50] Batch 200/674 | Loss D: 1.5450 | Loss G: 1.2197
# Época [1/50] Batch 300/674 | Loss D: 1.5428 | Loss G: 0.9378
# Época [1/50] Batch 400/674 | Loss D: 1.4760 | Loss G: 1.3657
# Época [1/50] Batch 500/674 | Loss D: 1.0429 | Loss G: 1.5071
# Época [1/50] Batch 600/674 | Loss D: 1.6572 | Loss G: 0.7595
# --> [FIM DA ÉPOCA 1] Amostra visual salva em: /content/images_dgan/anime_epoch_1.png
#
# Época [2/50] Batch 0/674 | Loss D: 1.4074 | Loss G: 1.2639
# Época [2/50] Batch 100/674 | Loss D: 1.4109 | Loss G: 1.2657
# Época [2/50] Batch 200/674 | Loss D: 1.4165 | Loss G: 0.9224
# Época [2/50] Batch 300/674 | Loss D: 1.5114 | Loss G: 1.7279
# Época [2/50] Batch 400/674 | Loss D: 1.4079 | Loss G: 1.2694
# Época [2/50] Batch 500/674 | Loss D: 1.5206 | Loss G: 1.4926
# Época [2/50] Batch 600/674 | Loss D: 1.4213 | Loss G: 1.2971
# --> [FIM DA ÉPOCA 2] Amostra visual salva em: /content/images_dgan/anime_epoch_2.png
#
# Época [3/50] Batch 0/674 | Loss D: 1.4718 | Loss G: 1.0120
# Época [3/50] Batch 100/674 | Loss D: 1.6042 | Loss G: 1.8442
# Época [3/50] Batch 200/674 | Loss D: 1.4088 | Loss G: 1.1454
# Época [3/50] Batch 300/674 | Loss D: 1.6412 | Loss G: 0.7258
# Época [3/50] Batch 400/674 | Loss D: 1.3617 | Loss G: 1.5168
# Época [3/50] Batch 500/674 | Loss D: 1.3473 | Loss G: 1.5990
# Época [3/50] Batch 600/674 | Loss D: 1.3627 | Loss G: 1.3324
# --> [FIM DA ÉPOCA 3] Amostra visual salva em: /content/images_dgan/anime_epoch_3.png
#
# Época [4/50] Batch 0/674 | Loss D: 1.2442 | Loss G: 1.1721
# Época [4/50] Batch 100/674 | Loss D: 1.3764 | Loss G: 1.1711
# Época [4/50] Batch 200/674 | Loss D: 1.6383 | Loss G: 1.5055
# Época [4/50] Batch 300/674 | Loss D: 1.4915 | Loss G: 1.1880
# Época [4/50] Batch 400/674 | Loss D: 1.4727 | Loss G: 1.3334
# Época [4/50] Batch 500/674 | Loss D: 1.3480 | Loss G: 1.3573
# Época [4/50] Batch 600/674 | Loss D: 1.3939 | Loss G: 1.1428
# --> [FIM DA ÉPOCA 4] Amostra visual salva em: /content/images_dgan/anime_epoch_4.png
#
# Época [5/50] Batch 0/674 | Loss D: 1.3988 | Loss G: 1.4236
# Época [5/50] Batch 100/674 | Loss D: 1.3141 | Loss G: 1.3023
# Época [5/50] Batch 200/674 | Loss D: 1.6296 | Loss G: 1.7603
# Época [5/50] Batch 300/674 | Loss D: 1.3177 | Loss G: 1.4040
# Época [5/50] Batch 400/674 | Loss D: 1.6000 | Loss G: 0.8510
# Época [5/50] Batch 500/674 | Loss D: 1.2567 | Loss G: 1.3791
# Época [5/50] Batch 600/674 | Loss D: 1.4257 | Loss G: 0.9992
# --> [FIM DA ÉPOCA 5] Amostra visual salva em: /content/images_dgan/anime_epoch_5.png
#
# Época [6/50] Batch 0/674 | Loss D: 1.7307 | Loss G: 2.3266
# Época [6/50] Batch 100/674 | Loss D: 1.3719 | Loss G: 1.4651
# Época [6/50] Batch 200/674 | Loss D: 1.3687 | Loss G: 1.5284
# Época [6/50] Batch 300/674 | Loss D: 1.4287 | Loss G: 1.0892
# Época [6/50] Batch 400/674 | Loss D: 1.3829 | Loss G: 1.4721
# Época [6/50] Batch 500/674 | Loss D: 1.3486 | Loss G: 1.2742
# Época [6/50] Batch 600/674 | Loss D: 1.2773 | Loss G: 1.2500
# --> [FIM DA ÉPOCA 6] Amostra visual salva em: /content/images_dgan/anime_epoch_6.png
#
# Época [7/50] Batch 0/674 | Loss D: 1.5160 | Loss G: 0.7536
# Época [7/50] Batch 100/674 | Loss D: 1.3444 | Loss G: 1.8868
# Época [7/50] Batch 200/674 | Loss D: 1.2389 | Loss G: 1.3793
# Época [7/50] Batch 300/674 | Loss D: 1.3314 | Loss G: 1.4235
# Época [7/50] Batch 400/674 | Loss D: 1.5517 | Loss G: 0.7301
# Época [7/50] Batch 500/674 | Loss D: 1.2409 | Loss G: 1.4478
# Época [7/50] Batch 600/674 | Loss D: 1.6191 | Loss G: 1.8680
# --> [FIM DA ÉPOCA 7] Amostra visual salva em: /content/images_dgan/anime_epoch_7.png
#
# Época [8/50] Batch 0/674 | Loss D: 1.3118 | Loss G: 1.5488
# Época [8/50] Batch 100/674 | Loss D: 1.2636 | Loss G: 1.0873
# Época [8/50] Batch 200/674 | Loss D: 1.3693 | Loss G: 1.4591
# Época [8/50] Batch 300/674 | Loss D: 1.3648 | Loss G: 1.3246
# Época [8/50] Batch 400/674 | Loss D: 1.3946 | Loss G: 1.5345
# Época [8/50] Batch 500/674 | Loss D: 1.3703 | Loss G: 1.1710
# Época [8/50] Batch 600/674 | Loss D: 1.2107 | Loss G: 1.1174
# --> [FIM DA ÉPOCA 8] Amostra visual salva em: /content/images_dgan/anime_epoch_8.png
#
# Época [9/50] Batch 0/674 | Loss D: 1.2380 | Loss G: 1.0989
# Época [9/50] Batch 100/674 | Loss D: 1.3275 | Loss G: 1.1378
# Época [9/50] Batch 200/674 | Loss D: 1.3541 | Loss G: 0.9721
# Época [9/50] Batch 300/674 | Loss D: 1.1157 | Loss G: 1.6610
# Época [9/50] Batch 400/674 | Loss D: 1.2384 | Loss G: 1.1634
# Época [9/50] Batch 500/674 | Loss D: 1.3673 | Loss G: 2.4129
# Época [9/50] Batch 600/674 | Loss D: 1.3037 | Loss G: 0.8952
# --> [FIM DA ÉPOCA 9] Amostra visual salva em: /content/images_dgan/anime_epoch_9.png
#
# Época [10/50] Batch 0/674 | Loss D: 1.2725 | Loss G: 1.1510
# Época [10/50] Batch 100/674 | Loss D: 1.2588 | Loss G: 1.0945
# Época [10/50] Batch 200/674 | Loss D: 1.1672 | Loss G: 1.3730
# Época [10/50] Batch 300/674 | Loss D: 1.3084 | Loss G: 1.4021
# Época [10/50] Batch 400/674 | Loss D: 1.5047 | Loss G: 1.0760
# Época [10/50] Batch 500/674 | Loss D: 1.1798 | Loss G: 1.2990
# Época [10/50] Batch 600/674 | Loss D: 1.2698 | Loss G: 1.9900
# --> [FIM DA ÉPOCA 10] Amostra visual salva em: /content/images_dgan/anime_epoch_10.png
#
# Época [11/50] Batch 0/674 | Loss D: 1.2751 | Loss G: 1.1191
# Época [11/50] Batch 100/674 | Loss D: 1.2669 | Loss G: 1.6498
# Época [11/50] Batch 200/674 | Loss D: 1.2129 | Loss G: 1.6197
# Época [11/50] Batch 300/674 | Loss D: 1.1670 | Loss G: 1.4604
# Época [11/50] Batch 400/674 | Loss D: 1.1893 | Loss G: 1.4966
# Época [11/50] Batch 500/674 | Loss D: 1.2512 | Loss G: 1.4734
# Época [11/50] Batch 600/674 | Loss D: 1.1730 | Loss G: 1.2952
# --> [FIM DA ÉPOCA 11] Amostra visual salva em: /content/images_dgan/anime_epoch_11.png
#
# Época [12/50] Batch 0/674 | Loss D: 1.2451 | Loss G: 1.7340
# Época [12/50] Batch 100/674 | Loss D: 1.1395 | Loss G: 1.4936
# Época [12/50] Batch 200/674 | Loss D: 1.2160 | Loss G: 1.6676
# Época [12/50] Batch 300/674 | Loss D: 1.2215 | Loss G: 1.9834
# Época [12/50] Batch 400/674 | Loss D: 1.1529 | Loss G: 1.4535
# Época [12/50] Batch 500/674 | Loss D: 1.2005 | Loss G: 2.3597
# Época [12/50] Batch 600/674 | Loss D: 1.2909 | Loss G: 0.9294
# --> [FIM DA ÉPOCA 12] Amostra visual salva em: /content/images_dgan/anime_epoch_12.png
#
# Época [13/50] Batch 0/674 | Loss D: 1.2137 | Loss G: 1.2596
# Época [13/50] Batch 100/674 | Loss D: 1.2009 | Loss G: 1.4127
# Época [13/50] Batch 200/674 | Loss D: 1.2393 | Loss G: 0.9663
# Época [13/50] Batch 300/674 | Loss D: 1.0879 | Loss G: 1.4720
# Época [13/50] Batch 400/674 | Loss D: 1.1728 | Loss G: 1.4830
# Época [13/50] Batch 500/674 | Loss D: 1.0993 | Loss G: 1.2105
# Época [13/50] Batch 600/674 | Loss D: 1.1383 | Loss G: 2.0745
# --> [FIM DA ÉPOCA 13] Amostra visual salva em: /content/images_dgan/anime_epoch_13.png
#
# Época [14/50] Batch 0/674 | Loss D: 1.1987 | Loss G: 0.8069
# Época [14/50] Batch 100/674 | Loss D: 1.0097 | Loss G: 1.7561
# Época [14/50] Batch 200/674 | Loss D: 1.0849 | Loss G: 1.1866
# Época [14/50] Batch 300/674 | Loss D: 1.1485 | Loss G: 1.5514
# Época [14/50] Batch 400/674 | Loss D: 1.2358 | Loss G: 1.0664
# Época [14/50] Batch 500/674 | Loss D: 1.0573 | Loss G: 1.5104
# Época [14/50] Batch 600/674 | Loss D: 1.4507 | Loss G: 1.1068
# --> [FIM DA ÉPOCA 14] Amostra visual salva em: /content/images_dgan/anime_epoch_14.png
#
# Época [15/50] Batch 0/674 | Loss D: 1.0908 | Loss G: 1.5914
# Época [15/50] Batch 100/674 | Loss D: 1.0105 | Loss G: 1.4472
# Época [15/50] Batch 200/674 | Loss D: 1.3493 | Loss G: 0.8010
# Época [15/50] Batch 300/674 | Loss D: 1.3442 | Loss G: 2.7740
# Época [15/50] Batch 400/674 | Loss D: 1.2021 | Loss G: 1.9753
# Época [15/50] Batch 500/674 | Loss D: 0.9826 | Loss G: 1.7717
# Época [15/50] Batch 600/674 | Loss D: 1.1103 | Loss G: 1.2749
# --> [FIM DA ÉPOCA 15] Amostra visual salva em: /content/images_dgan/anime_epoch_15.png
#
# Época [16/50] Batch 0/674 | Loss D: 1.2273 | Loss G: 1.9944
# Época [16/50] Batch 100/674 | Loss D: 1.2480 | Loss G: 2.4640
# Época [16/50] Batch 200/674 | Loss D: 1.1132 | Loss G: 1.6980
# Época [16/50] Batch 300/674 | Loss D: 1.0676 | Loss G: 1.6500
# Época [16/50] Batch 400/674 | Loss D: 1.0075 | Loss G: 1.8328
# Época [16/50] Batch 500/674 | Loss D: 0.9791 | Loss G: 1.4576
# Época [16/50] Batch 600/674 | Loss D: 0.9166 | Loss G: 1.5049
# --> [FIM DA ÉPOCA 16] Amostra visual salva em: /content/images_dgan/anime_epoch_16.png
#
# Época [17/50] Batch 0/674 | Loss D: 1.0297 | Loss G: 2.2740
# Época [17/50] Batch 100/674 | Loss D: 1.1054 | Loss G: 1.4228
# Época [17/50] Batch 200/674 | Loss D: 1.1917 | Loss G: 2.8378
# Época [17/50] Batch 300/674 | Loss D: 1.1244 | Loss G: 0.9332
# Época [17/50] Batch 400/674 | Loss D: 1.0482 | Loss G: 2.0315
# Época [17/50] Batch 500/674 | Loss D: 0.9968 | Loss G: 2.4415
# Época [17/50] Batch 600/674 | Loss D: 1.4422 | Loss G: 2.6636
# --> [FIM DA ÉPOCA 17] Amostra visual salva em: /content/images_dgan/anime_epoch_17.png
#
# Época [18/50] Batch 0/674 | Loss D: 1.1838 | Loss G: 0.9155
# Época [18/50] Batch 100/674 | Loss D: 0.9841 | Loss G: 2.1831
# Época [18/50] Batch 200/674 | Loss D: 0.9731 | Loss G: 1.9743
# Época [18/50] Batch 300/674 | Loss D: 0.9115 | Loss G: 1.1879
# Época [18/50] Batch 400/674 | Loss D: 0.9887 | Loss G: 1.8590
# Época [18/50] Batch 500/674 | Loss D: 0.9788 | Loss G: 1.9511
# Época [18/50] Batch 600/674 | Loss D: 1.0918 | Loss G: 2.1654
# --> [FIM DA ÉPOCA 18] Amostra visual salva em: /content/images_dgan/anime_epoch_18.png
#
# Época [19/50] Batch 0/674 | Loss D: 1.2478 | Loss G: 2.7794
# Época [19/50] Batch 100/674 | Loss D: 0.9965 | Loss G: 1.8970
# Época [19/50] Batch 200/674 | Loss D: 1.0990 | Loss G: 2.5101
# Época [19/50] Batch 300/674 | Loss D: 0.8951 | Loss G: 2.1639
# Época [19/50] Batch 400/674 | Loss D: 1.3079 | Loss G: 0.8517
# Época [19/50] Batch 500/674 | Loss D: 0.9796 | Loss G: 1.1058
# Época [19/50] Batch 600/674 | Loss D: 0.9059 | Loss G: 1.3484
# --> [FIM DA ÉPOCA 19] Amostra visual salva em: /content/images_dgan/anime_epoch_19.png
#
# Época [20/50] Batch 0/674 | Loss D: 0.9284 | Loss G: 2.7001
# Época [20/50] Batch 100/674 | Loss D: 0.8614 | Loss G: 2.1810
# Época [20/50] Batch 200/674 | Loss D: 0.8607 | Loss G: 1.4788
# Época [20/50] Batch 300/674 | Loss D: 0.8797 | Loss G: 1.9993
# Época [20/50] Batch 400/674 | Loss D: 0.9482 | Loss G: 2.8827
# Época [20/50] Batch 500/674 | Loss D: 1.2329 | Loss G: 0.9333
# Época [20/50] Batch 600/674 | Loss D: 0.9619 | Loss G: 2.7226
# --> [FIM DA ÉPOCA 20] Amostra visual salva em: /content/images_dgan/anime_epoch_20.png
#
# Época [21/50] Batch 0/674 | Loss D: 0.8389 | Loss G: 2.0796
# Época [21/50] Batch 100/674 | Loss D: 1.0682 | Loss G: 1.3278
# Época [21/50] Batch 200/674 | Loss D: 0.9836 | Loss G: 1.0202
# Época [21/50] Batch 300/674 | Loss D: 1.1405 | Loss G: 3.5739
# Época [21/50] Batch 400/674 | Loss D: 0.8375 | Loss G: 2.4130
# Época [21/50] Batch 500/674 | Loss D: 0.8112 | Loss G: 2.0893
# Época [21/50] Batch 600/674 | Loss D: 0.8525 | Loss G: 1.5037
# --> [FIM DA ÉPOCA 21] Amostra visual salva em: /content/images_dgan/anime_epoch_21.png
#
# Época [22/50] Batch 0/674 | Loss D: 0.7305 | Loss G: 2.0053
# Época [22/50] Batch 100/674 | Loss D: 0.8073 | Loss G: 1.8770
# Época [22/50] Batch 200/674 | Loss D: 0.8811 | Loss G: 2.8073
# Época [22/50] Batch 300/674 | Loss D: 0.9100 | Loss G: 1.5368
# Época [22/50] Batch 400/674 | Loss D: 0.6928 | Loss G: 2.4200
# Época [22/50] Batch 500/674 | Loss D: 0.7551 | Loss G: 1.8486
# Época [22/50] Batch 600/674 | Loss D: 0.9064 | Loss G: 1.5635
# --> [FIM DA ÉPOCA 22] Amostra visual salva em: /content/images_dgan/anime_epoch_22.png
#
# Época [23/50] Batch 0/674 | Loss D: 0.7338 | Loss G: 2.7390
# Época [23/50] Batch 100/674 | Loss D: 0.9759 | Loss G: 0.9807
# Época [23/50] Batch 200/674 | Loss D: 0.7255 | Loss G: 1.9870
# Época [23/50] Batch 300/674 | Loss D: 0.7216 | Loss G: 2.1908
# Época [23/50] Batch 400/674 | Loss D: 0.7498 | Loss G: 2.1081
# Época [23/50] Batch 500/674 | Loss D: 0.7627 | Loss G: 2.5808
# Época [23/50] Batch 600/674 | Loss D: 0.7386 | Loss G: 2.2206
# --> [FIM DA ÉPOCA 23] Amostra visual salva em: /content/images_dgan/anime_epoch_23.png
#
# Época [24/50] Batch 0/674 | Loss D: 0.6822 | Loss G: 1.5882
# Época [24/50] Batch 100/674 | Loss D: 0.7049 | Loss G: 1.9004
# Época [24/50] Batch 200/674 | Loss D: 0.6153 | Loss G: 2.3511
# Época [24/50] Batch 300/674 | Loss D: 0.6938 | Loss G: 2.0227
# Época [24/50] Batch 400/674 | Loss D: 0.7636 | Loss G: 2.1060
# Época [24/50] Batch 500/674 | Loss D: 0.7195 | Loss G: 2.3003
# Época [24/50] Batch 600/674 | Loss D: 0.7564 | Loss G: 1.5361
# --> [FIM DA ÉPOCA 24] Amostra visual salva em: /content/images_dgan/anime_epoch_24.png
#
# Época [25/50] Batch 0/674 | Loss D: 0.6842 | Loss G: 2.4418
# Época [25/50] Batch 100/674 | Loss D: 0.9640 | Loss G: 3.6746
# Época [25/50] Batch 200/674 | Loss D: 0.6434 | Loss G: 2.1187
# Época [25/50] Batch 300/674 | Loss D: 0.8252 | Loss G: 2.9999
# Época [25/50] Batch 400/674 | Loss D: 0.6512 | Loss G: 2.2888
# Época [25/50] Batch 500/674 | Loss D: 0.7035 | Loss G: 3.1926
# Época [25/50] Batch 600/674 | Loss D: 0.6771 | Loss G: 2.5924
# --> [FIM DA ÉPOCA 25] Amostra visual salva em: /content/images_dgan/anime_epoch_25.png
#
# Época [26/50] Batch 0/674 | Loss D: 0.6137 | Loss G: 2.6450
# Época [26/50] Batch 100/674 | Loss D: 0.6644 | Loss G: 1.7116
# Época [26/50] Batch 200/674 | Loss D: 0.7569 | Loss G: 3.1432
# Época [26/50] Batch 300/674 | Loss D: 0.8155 | Loss G: 1.4953
# Época [26/50] Batch 400/674 | Loss D: 0.6048 | Loss G: 2.2720
# Época [26/50] Batch 500/674 | Loss D: 0.7563 | Loss G: 1.7487
# Época [26/50] Batch 600/674 | Loss D: 0.7338 | Loss G: 2.9744
# --> [FIM DA ÉPOCA 26] Amostra visual salva em: /content/images_dgan/anime_epoch_26.png
#
# Época [27/50] Batch 0/674 | Loss D: 0.8659 | Loss G: 3.8730
# Época [27/50] Batch 100/674 | Loss D: 0.5953 | Loss G: 1.7130
# Época [27/50] Batch 200/674 | Loss D: 0.6761 | Loss G: 3.1779
# Época [27/50] Batch 300/674 | Loss D: 0.5711 | Loss G: 2.3973
# Época [27/50] Batch 400/674 | Loss D: 0.7689 | Loss G: 1.9844
# Época [27/50] Batch 500/674 | Loss D: 0.6932 | Loss G: 1.6622
# Época [27/50] Batch 600/674 | Loss D: 0.5892 | Loss G: 2.1767
# --> [FIM DA ÉPOCA 27] Amostra visual salva em: /content/images_dgan/anime_epoch_27.png
#
# Época [28/50] Batch 0/674 | Loss D: 0.5855 | Loss G: 2.5712
# Época [28/50] Batch 100/674 | Loss D: 1.0179 | Loss G: 1.6991
# Época [28/50] Batch 200/674 | Loss D: 0.6547 | Loss G: 1.8000
# Época [28/50] Batch 300/674 | Loss D: 0.6289 | Loss G: 2.0487
# Época [28/50] Batch 400/674 | Loss D: 0.5754 | Loss G: 2.2042
# Época [28/50] Batch 500/674 | Loss D: 0.5914 | Loss G: 2.5824
# Época [28/50] Batch 600/674 | Loss D: 0.5767 | Loss G: 1.8493
# --> [FIM DA ÉPOCA 28] Amostra visual salva em: /content/images_dgan/anime_epoch_28.png
#
# Época [29/50] Batch 0/674 | Loss D: 0.5500 | Loss G: 3.4010
# Época [29/50] Batch 100/674 | Loss D: 0.8811 | Loss G: 4.3486
# Época [29/50] Batch 200/674 | Loss D: 0.6371 | Loss G: 2.7981
# Época [29/50] Batch 300/674 | Loss D: 0.8503 | Loss G: 3.9033
# Época [29/50] Batch 400/674 | Loss D: 0.5826 | Loss G: 2.2314
# Época [29/50] Batch 500/674 | Loss D: 0.6467 | Loss G: 1.7935
# Época [29/50] Batch 600/674 | Loss D: 0.5503 | Loss G: 2.0467
# --> [FIM DA ÉPOCA 29] Amostra visual salva em: /content/images_dgan/anime_epoch_29.png
#
# Época [30/50] Batch 0/674 | Loss D: 0.5516 | Loss G: 3.2384
# Época [30/50] Batch 100/674 | Loss D: 0.6937 | Loss G: 3.5775
# Época [30/50] Batch 200/674 | Loss D: 0.5476 | Loss G: 1.6296
# Época [30/50] Batch 300/674 | Loss D: 0.5140 | Loss G: 3.2256
# Época [30/50] Batch 400/674 | Loss D: 0.6091 | Loss G: 2.1120
# Época [30/50] Batch 500/674 | Loss D: 0.5046 | Loss G: 2.5544
# Época [30/50] Batch 600/674 | Loss D: 0.6344 | Loss G: 3.5178
# --> [FIM DA ÉPOCA 30] Amostra visual salva em: /content/images_dgan/anime_epoch_30.png
#
# Época [31/50] Batch 0/674 | Loss D: 1.1959 | Loss G: 6.3896
# Época [31/50] Batch 100/674 | Loss D: 0.4892 | Loss G: 2.9929
# Época [31/50] Batch 200/674 | Loss D: 0.5344 | Loss G: 2.2166
# Época [31/50] Batch 300/674 | Loss D: 0.5084 | Loss G: 2.3477
# Época [31/50] Batch 400/674 | Loss D: 0.4959 | Loss G: 2.6600
# Época [31/50] Batch 500/674 | Loss D: 0.6979 | Loss G: 1.7767
# Época [31/50] Batch 600/674 | Loss D: 0.5438 | Loss G: 2.4935
# --> [FIM DA ÉPOCA 31] Amostra visual salva em: /content/images_dgan/anime_epoch_31.png
#
# Época [32/50] Batch 0/674 | Loss D: 0.4957 | Loss G: 2.8496
# Época [32/50] Batch 100/674 | Loss D: 0.5314 | Loss G: 3.2234
# Época [32/50] Batch 200/674 | Loss D: 0.5497 | Loss G: 3.8170
# Época [32/50] Batch 300/674 | Loss D: 0.5318 | Loss G: 3.3631
# Época [32/50] Batch 400/674 | Loss D: 0.8889 | Loss G: 1.0176
# Época [32/50] Batch 500/674 | Loss D: 0.5542 | Loss G: 2.5419
# Época [32/50] Batch 600/674 | Loss D: 0.5027 | Loss G: 2.5417
# --> [FIM DA ÉPOCA 32] Amostra visual salva em: /content/images_dgan/anime_epoch_32.png
#
# Época [33/50] Batch 0/674 | Loss D: 0.5187 | Loss G: 2.1102
# Época [33/50] Batch 100/674 | Loss D: 0.4425 | Loss G: 3.2380
# Época [33/50] Batch 200/674 | Loss D: 0.4722 | Loss G: 3.1852
# Época [33/50] Batch 300/674 | Loss D: 0.5566 | Loss G: 2.0265
# Época [33/50] Batch 400/674 | Loss D: 0.4730 | Loss G: 2.7565
# Época [33/50] Batch 500/674 | Loss D: 0.4677 | Loss G: 2.8516
# Época [33/50] Batch 600/674 | Loss D: 0.6980 | Loss G: 4.9231
# --> [FIM DA ÉPOCA 33] Amostra visual salva em: /content/images_dgan/anime_epoch_33.png
#
# Época [34/50] Batch 0/674 | Loss D: 0.5498 | Loss G: 4.1296
# Época [34/50] Batch 100/674 | Loss D: 0.6850 | Loss G: 4.3778
# Época [34/50] Batch 200/674 | Loss D: 0.7424 | Loss G: 1.4905
# Época [34/50] Batch 300/674 | Loss D: 0.4451 | Loss G: 2.5463
# Época [34/50] Batch 400/674 | Loss D: 0.4587 | Loss G: 3.0710
# Época [34/50] Batch 500/674 | Loss D: 0.5455 | Loss G: 2.1198
# Época [34/50] Batch 600/674 | Loss D: 0.7986 | Loss G: 1.7085
# --> [FIM DA ÉPOCA 34] Amostra visual salva em: /content/images_dgan/anime_epoch_34.png
#
# Época [35/50] Batch 0/674 | Loss D: 0.6573 | Loss G: 4.3590
# Época [35/50] Batch 100/674 | Loss D: 0.4405 | Loss G: 3.2590
# Época [35/50] Batch 200/674 | Loss D: 0.4646 | Loss G: 2.9448
# Época [35/50] Batch 300/674 | Loss D: 0.4882 | Loss G: 3.4616
# Época [35/50] Batch 400/674 | Loss D: 0.4575 | Loss G: 3.4454
# Época [35/50] Batch 500/674 | Loss D: 0.4006 | Loss G: 3.5123
# Época [35/50] Batch 600/674 | Loss D: 0.5087 | Loss G: 2.3517
# --> [FIM DA ÉPOCA 35] Amostra visual salva em: /content/images_dgan/anime_epoch_35.png
#
# Época [36/50] Batch 0/674 | Loss D: 0.4572 | Loss G: 3.3891
# Época [36/50] Batch 100/674 | Loss D: 0.4339 | Loss G: 3.2582
# Época [36/50] Batch 200/674 | Loss D: 0.4075 | Loss G: 3.3711
# Época [36/50] Batch 300/674 | Loss D: 0.4206 | Loss G: 3.7484
# Época [36/50] Batch 400/674 | Loss D: 0.5376 | Loss G: 2.9812
# Época [36/50] Batch 500/674 | Loss D: 0.4376 | Loss G: 2.9820
# Época [36/50] Batch 600/674 | Loss D: 0.4230 | Loss G: 3.3999
# --> [FIM DA ÉPOCA 36] Amostra visual salva em: /content/images_dgan/anime_epoch_36.png
#
# Época [37/50] Batch 0/674 | Loss D: 0.5372 | Loss G: 4.0198
# Época [37/50] Batch 100/674 | Loss D: 0.4401 | Loss G: 2.6921
# Época [37/50] Batch 200/674 | Loss D: 0.4746 | Loss G: 2.4291
# Época [37/50] Batch 300/674 | Loss D: 0.3899 | Loss G: 3.5878
# Época [37/50] Batch 400/674 | Loss D: 0.5118 | Loss G: 3.7940
# Época [37/50] Batch 500/674 | Loss D: 0.5776 | Loss G: 3.1227
# Época [37/50] Batch 600/674 | Loss D: 0.5292 | Loss G: 1.7211
# --> [FIM DA ÉPOCA 37] Amostra visual salva em: /content/images_dgan/anime_epoch_37.png
#
# Época [38/50] Batch 0/674 | Loss D: 0.4237 | Loss G: 3.0399
# Época [38/50] Batch 100/674 | Loss D: 0.4190 | Loss G: 2.9384
# Época [38/50] Batch 200/674 | Loss D: 0.4262 | Loss G: 3.1963
# Época [38/50] Batch 300/674 | Loss D: 0.4186 | Loss G: 2.8122
# Época [38/50] Batch 400/674 | Loss D: 0.4864 | Loss G: 3.7248
# Época [38/50] Batch 500/674 | Loss D: 0.4216 | Loss G: 3.2588
# Época [38/50] Batch 600/674 | Loss D: 0.5324 | Loss G: 4.4673
# --> [FIM DA ÉPOCA 38] Amostra visual salva em: /content/images_dgan/anime_epoch_38.png
#
# Época [39/50] Batch 0/674 | Loss D: 0.4339 | Loss G: 3.5125
# Época [39/50] Batch 100/674 | Loss D: 0.5660 | Loss G: 4.2790
# Época [39/50] Batch 200/674 | Loss D: 0.6308 | Loss G: 3.4106
# Época [39/50] Batch 300/674 | Loss D: 0.4263 | Loss G: 3.1120
# Época [39/50] Batch 400/674 | Loss D: 0.4547 | Loss G: 2.9065
# Época [39/50] Batch 500/674 | Loss D: 0.4175 | Loss G: 3.3642
# Época [39/50] Batch 600/674 | Loss D: 0.5582 | Loss G: 1.3845
# --> [FIM DA ÉPOCA 39] Amostra visual salva em: /content/images_dgan/anime_epoch_39.png
#
# Época [40/50] Batch 0/674 | Loss D: 0.4231 | Loss G: 3.1801
# Época [40/50] Batch 100/674 | Loss D: 0.4036 | Loss G: 3.6915
# Época [40/50] Batch 200/674 | Loss D: 0.4070 | Loss G: 3.3920
# Época [40/50] Batch 300/674 | Loss D: 0.3875 | Loss G: 3.6474
# Época [40/50] Batch 400/674 | Loss D: 0.6855 | Loss G: 4.4273
# Época [40/50] Batch 500/674 | Loss D: 0.4631 | Loss G: 3.2028
# Época [40/50] Batch 600/674 | Loss D: 0.4397 | Loss G: 3.0837
# --> [FIM DA ÉPOCA 40] Amostra visual salva em: /content/images_dgan/anime_epoch_40.png
#
# Época [41/50] Batch 0/674 | Loss D: 0.4667 | Loss G: 4.4371
# Época [41/50] Batch 100/674 | Loss D: 0.4466 | Loss G: 4.2966
# Época [41/50] Batch 200/674 | Loss D: 1.8723 | Loss G: 7.7219
# Época [41/50] Batch 300/674 | Loss D: 0.4204 | Loss G: 3.5944
# Época [41/50] Batch 400/674 | Loss D: 0.4295 | Loss G: 2.6149
# Época [41/50] Batch 500/674 | Loss D: 0.4112 | Loss G: 3.3686
# Época [41/50] Batch 600/674 | Loss D: 0.4684 | Loss G: 4.1286
# --> [FIM DA ÉPOCA 41] Amostra visual salva em: /content/images_dgan/anime_epoch_41.png
#
# Época [42/50] Batch 0/674 | Loss D: 0.4519 | Loss G: 3.1732
# Época [42/50] Batch 100/674 | Loss D: 0.3947 | Loss G: 3.9454
# Época [42/50] Batch 200/674 | Loss D: 0.4081 | Loss G: 3.6699
# Época [42/50] Batch 300/674 | Loss D: 0.3914 | Loss G: 3.3882
# Época [42/50] Batch 400/674 | Loss D: 0.4100 | Loss G: 4.0540
# Época [42/50] Batch 500/674 | Loss D: 0.4523 | Loss G: 2.6345
# Época [42/50] Batch 600/674 | Loss D: 0.6946 | Loss G: 2.4304
# --> [FIM DA ÉPOCA 42] Amostra visual salva em: /content/images_dgan/anime_epoch_42.png
#
# Época [43/50] Batch 0/674 | Loss D: 0.4568 | Loss G: 4.3839
# Época [43/50] Batch 100/674 | Loss D: 0.4150 | Loss G: 3.4100
# Época [43/50] Batch 200/674 | Loss D: 0.3927 | Loss G: 4.3270
# Época [43/50] Batch 300/674 | Loss D: 0.5134 | Loss G: 2.4380
# Época [43/50] Batch 400/674 | Loss D: 0.3857 | Loss G: 4.0835
# Época [43/50] Batch 500/674 | Loss D: 0.4568 | Loss G: 2.9302
# Época [43/50] Batch 600/674 | Loss D: 0.4348 | Loss G: 4.4200
# --> [FIM DA ÉPOCA 43] Amostra visual salva em: /content/images_dgan/anime_epoch_43.png
#
# Época [44/50] Batch 0/674 | Loss D: 0.5201 | Loss G: 2.4631
# Época [44/50] Batch 100/674 | Loss D: 0.3825 | Loss G: 3.8483
# Época [44/50] Batch 200/674 | Loss D: 0.4935 | Loss G: 3.4672
# Época [44/50] Batch 300/674 | Loss D: 0.4396 | Loss G: 3.8166
# Época [44/50] Batch 400/674 | Loss D: 0.4331 | Loss G: 2.4794
# Época [44/50] Batch 500/674 | Loss D: 0.4037 | Loss G: 4.2499
# Época [44/50] Batch 600/674 | Loss D: 0.3918 | Loss G: 3.8651
# --> [FIM DA ÉPOCA 44] Amostra visual salva em: /content/images_dgan/anime_epoch_44.png
#
# Época [45/50] Batch 0/674 | Loss D: 0.3846 | Loss G: 4.5316
# Época [45/50] Batch 100/674 | Loss D: 0.3837 | Loss G: 4.6805
# Época [45/50] Batch 200/674 | Loss D: 0.3882 | Loss G: 3.5060
# Época [45/50] Batch 300/674 | Loss D: 0.4120 | Loss G: 4.0289
# Época [45/50] Batch 400/674 | Loss D: 0.3853 | Loss G: 3.7496
# Época [45/50] Batch 500/674 | Loss D: 0.3970 | Loss G: 3.7742
# Época [45/50] Batch 600/674 | Loss D: 0.3947 | Loss G: 3.2430
# --> [FIM DA ÉPOCA 45] Amostra visual salva em: /content/images_dgan/anime_epoch_45.png
#
# Época [46/50] Batch 0/674 | Loss D: 0.4036 | Loss G: 4.4253
# Época [46/50] Batch 100/674 | Loss D: 0.3992 | Loss G: 3.3301
# Época [46/50] Batch 200/674 | Loss D: 0.3969 | Loss G: 3.9943
# Época [46/50] Batch 300/674 | Loss D: 0.4044 | Loss G: 4.5597
# Época [46/50] Batch 400/674 | Loss D: 0.8293 | Loss G: 3.6573
# Época [46/50] Batch 500/674 | Loss D: 0.4379 | Loss G: 3.3879
# Época [46/50] Batch 600/674 | Loss D: 0.4391 | Loss G: 3.6752
# --> [FIM DA ÉPOCA 46] Amostra visual salva em: /content/images_dgan/anime_epoch_46.png
#
# Época [47/50] Batch 0/674 | Loss D: 0.5298 | Loss G: 4.0469
# Época [47/50] Batch 100/674 | Loss D: 0.3932 | Loss G: 4.0941
# Época [47/50] Batch 200/674 | Loss D: 0.3784 | Loss G: 3.7504
# Época [47/50] Batch 300/674 | Loss D: 0.3751 | Loss G: 4.1139
# Época [47/50] Batch 400/674 | Loss D: 0.5278 | Loss G: 4.2444
# Época [47/50] Batch 500/674 | Loss D: 0.3888 | Loss G: 4.3861
# Época [47/50] Batch 600/674 | Loss D: 0.3977 | Loss G: 3.3111
# --> [FIM DA ÉPOCA 47] Amostra visual salva em: /content/images_dgan/anime_epoch_47.png
#
# Época [48/50] Batch 0/674 | Loss D: 0.3730 | Loss G: 4.4845
# Época [48/50] Batch 100/674 | Loss D: 0.3909 | Loss G: 3.6516
# Época [48/50] Batch 200/674 | Loss D: 0.3870 | Loss G: 3.9805
# Época [48/50] Batch 300/674 | Loss D: 0.3843 | Loss G: 3.7100
# Época [48/50] Batch 400/674 | Loss D: 0.4282 | Loss G: 3.3339
# Época [48/50] Batch 500/674 | Loss D: 0.3744 | Loss G: 3.7375
# Época [48/50] Batch 600/674 | Loss D: 0.4282 | Loss G: 4.0877
# --> [FIM DA ÉPOCA 48] Amostra visual salva em: /content/images_dgan/anime_epoch_48.png
#
# Época [49/50] Batch 0/674 | Loss D: 0.3932 | Loss G: 4.2286
# Época [49/50] Batch 100/674 | Loss D: 0.3916 | Loss G: 3.4841
# Época [49/50] Batch 200/674 | Loss D: 0.4067 | Loss G: 3.0453
# Época [49/50] Batch 300/674 | Loss D: 0.4132 | Loss G: 3.2109
# Época [49/50] Batch 400/674 | Loss D: 0.4116 | Loss G: 2.8806
# Época [49/50] Batch 500/674 | Loss D: 0.3749 | Loss G: 4.3124
# Época [49/50] Batch 600/674 | Loss D: 0.4329 | Loss G: 2.7881
# --> [FIM DA ÉPOCA 49] Amostra visual salva em: /content/images_dgan/anime_epoch_49.png

# %% [markdown]
# # Diagnóstico de Evolução Visual Lado a Lado
#
# Este bloco implementa um mecanismo automatizado de auditoria visual para rastrear a evolução estética do Gerador. Ele compara o estágio inicial do treinamento com os resultados mais recentes.
#
# ### Como funciona o algoritmo de varredura:
# 1. **Filtro de Diretório**: O script acessa a pasta local `/content/images_dgan` e filtra exclusivamente os arquivos com extensão `.png` que foram salvos pelo loop de treinamento.
# 2. **Ordenação Cronológica (`os.path.getmtime`)**: Utiliza os carimbos de data/hora do sistema operacional da máquina virtual para organizar a lista de imagens exatamente da mais antiga para a mais recente.
# 3. **Mapeamento de Casos**:
#     *   **`arquivos[0]`**: Captura o primeiríssimo arquivo gerado (`anime_epoch_0.png`). Ele representa o pior cenário estrutural da rede profunda, quando os filtros convolucionais do gerador ainda estão disparando pixels quase aleatórios.
#     *   **`arquivos[-1]`**: Isola dinamicamente a imagem gerada na época mais recente do seu treinamento atualizado.
# 4. **Renderização em Grade Lado a Lado**: Monta um painel comparativo paralelo dividindo a tela em duas colunas usando `plt.subplots(1, 2)`. Os eixos de contagem de pixels são desativados (`axis('off')`) para que você possa avaliar a nitidez dos rostos, olhos e traços geométricos sem interferência visual de bordas.

# %%
import matplotlib.pyplot as plt
from PIL import Image


def comparar_pior_e_melhor(pasta_imagens="/content/images_dgan"):
    if not os.path.exists(pasta_imagens):
        print(f"A pasta {pasta_imagens} não foi encontrada.")
        return

    # Filtra apenas arquivos de imagem PNG
    arquivos = [f for f in os.listdir(pasta_imagens) if f.endswith('.png')]

    if len(arquivos) < 2:
        print(f"Encontrados apenas {len(arquivos)} arquivo(s). Aguarde o treino avançar para comparar.")
        return

    # Ordena os arquivos pelo tempo de modificação/criação (do mais antigo para o mais recente)
    arquivos.sort(key=lambda x: os.path.getmtime(os.path.join(pasta_imagens, x)))

    pior_resultado = arquivos[0]   # A primeiríssima imagem gerada (pior caso estrutural)
    melhor_resultado = arquivos[-1] # A última imagem salva pelo seu treino atualizado

    # Criando a estrutura de plotagem lado a lado (1 linha, 2 colunas)
    fig, axes = plt.subplots(1, 2, figsize=(16, 8))

    # 1. Plotando o Pior Resultado
    caminho_pior = os.path.join(pasta_imagens, pior_resultado)
    img_pior = Image.open(caminho_pior)
    axes[0].imshow(img_pior)
    axes[0].set_title(f"❌ Início / Pior Caso\n({pior_resultado})", fontsize=14, color='red', fontweight='bold')
    axes[0].axis('off')

    # 2. Plotando o Melhor Resultado Atual
    caminho_melhor = os.path.join(pasta_imagens, melhor_resultado)
    img_melhor = Image.open(caminho_melhor)
    axes[1].imshow(img_melhor)
    axes[1].set_title(f"⭐ Evolução / Melhor Caso Atual\n({melhor_resultado})", fontsize=14, color='green', fontweight='bold')
    axes[1].axis('off')

    plt.tight_layout()
    plt.show()

# Executa o comparador geométrico na tela
comparar_pior_e_melhor()
# Out:
# /tmp/ipykernel_23020/3721918330.py:40: UserWarning: Glyph 10060 (\N{CROSS MARK}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_23020/3721918330.py:40: UserWarning: Glyph 11088 (\N{WHITE MEDIUM STAR}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 10060 (\N{CROSS MARK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 11088 (\N{WHITE MEDIUM STAR}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Teste de Interpolação Linear Contínua no Espaço Latente
#
# Este bloco executa a validação científica mais importante de uma rede generativa. Ele serve para provar matematicamente se o Gerador de fato compreendeu a topologia e a geometria das características dos rostos de anime, ou se ele apenas decorou e copiou fotos do dataset de treino (*overfitting*).
#
# ### 1. Preparação Rigorosa de Avaliação
# *   **`generator.eval()`**: Coloca o Gerador em modo de inferência (avaliação). Isso é vital para travar o comportamento das camadas de `BatchNorm2d`. Em modo de teste, a rede deve usar as médias globais acumuladas durante o treino em vez das estatísticas do lote, garantindo que a saída seja limpa e estável.
# *   **`torch.no_grad()`**: Desativa o motor de cálculo de derivadas (gradientes) do PyTorch. Como não estamos treinando as redes neste momento, essa linha economiza memória da GPU e acelera a renderização dos gráficos.
#
# ### 2. Sorteio no Hiperespaço 4D
# O código gera dois pontos completamente aleatórios e distintos no espaço latente de 100 dimensões: o vetor **`z1`** e o vetor **`z2`**. Graças ao nosso ajuste estrutural, eles já nascem no formato quadridimensional nativo de mapa de recursos `(1, 100, 1, 1)` exigido pelas novas camadas profundas do Gerador.
#
# Cada um desses dois vetores representa o DNA aleatório de um personagem único que a nossa inteligência artificial consegue desenhar.
#
# ### 3. A Caminhada Matemática (`np.linspace`)
# O laço de repetição cria 10 passos intermediários partindo do vetor `z1` em direção ao vetor `z2`. Para cada passo, a função calcula uma combinação linear ponderada utilizando o coeficiente **$\alpha$** (que varia gradualmente de 0.0 a 1.0):
#
# $$z_{interp} = (1 - \alpha) \cdot z_1 + \alpha \cdot z_2$$
#
# À medida que o $\alpha$ avança, o DNA do personagem inicial se transforma aos poucos no DNA do segundo personagem. O Gerador decodifica esses pequenos tensores intermediários em imagens.
#
# ### 4. Reconstrução de Cor e Exibição
# *   **Desnormalização Matemática**: O Gerador devolve os pixels na escala de `[-1.0, 1.0]`. Para que a biblioteca gráfica `matplotlib` consiga exibir as cores corretamente na sua tela, fazemos a operação inversa: somamos 1.0 e dividimos por 2.0, trazendo os pixels de volta para o intervalo padrão de `[0.0, 1.0]`.
# *   **`.permute(1, 2, 0)`**: Modifica o arranjo das dimensões do PyTorch (`canais, altura, largura`) para o padrão nativo adotado pelo ecossistema de imagens do Python (`altura, largura, canais`).
#
# ### 🔬 Como interpretar o gráfico na tela?
# *   **Se a transição for suave**: Você verá o primeiro rosto se transformando de forma fluida no segundo rosto (por exemplo, os cabelos mudando de cor aos poucos ou os olhos alterando o formato progressivamente a cada frame). **Isso prova que a sua GAN deu certo!** Significa que o espaço latente é contínuo e que a IA aprendeu as regras gerais de anatomia de anime.
# *   **Se a transição der saltos bruscos ou borrões**: Significa que o espaço latente está fraturado, uma indicação de que o modelo precisaria de mais épocas de treino ou de uma regularização mais intensa para suavizar suas distribuições internas.
#
# Por fim, o comando `generator.train()` devolve a rede com segurança para o estado de treinamento, permitindo que você continue rodando mais épocas caso queira refinar ainda mais os resultados.

# %%
# Garante que os modelos estão em modo de avaliação para desativar o BatchNorm
generator.eval()

with torch.no_grad():
    # AJUSTE: Amostragem dos pontos latentes diretamente no formato 4D (1, 100, 1, 1)
    z1 = torch.randn(1, latent_dim, 1, 1).to(device)
    z2 = torch.randn(1, latent_dim, 1, 1).to(device)

    passos = 10
    imagens_interpoladas = []

    for alpha in np.linspace(0, 1, passos):
        # Combinação linear dos vetores no espaço latente 4D
        z_interp = (1 - alpha) * z1 + alpha * z2

        # Gerar a imagem artificial correspondente
        img_falsa = generator(z_interp)

        # Desnormalizar de [-1, 1] para [0, 1] para o matplotlib plotar corretamente
        img_falsa = (img_falsa + 1) / 2
        img_falsa = img_falsa.clamp(0, 1).squeeze(0).cpu().permute(1, 2, 0).numpy()
        imagens_interpoladas.append(img_falsa)

    # Plotar a transição contínua na tela
    fig, axes = plt.subplots(1, passos, figsize=(20, 3))
    for idx, img in enumerate(imagens_interpoladas):
        axes[idx].imshow(img)
        axes[idx].axis('off')
        if idx == 0: axes[idx].set_title("Início (z1)")
        if idx == passos-1: axes[idx].set_title("Fim (z2)")

    plt.suptitle("Teste de Interpolação Avançado: Se a transição for suave, sua GAN deu certo!", fontsize=14, y=1.1)
    plt.show()

# Retorna o gerador para o modo de treino se você quiser continuar o treinamento
generator.train()
# Out:
# Generator(
#   (model): Sequential(
#     (0): ConvTranspose2d(100, 1024, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU(inplace=True)
#     (12): ConvTranspose2d(128, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (13): Tanh()
#   )
# )
